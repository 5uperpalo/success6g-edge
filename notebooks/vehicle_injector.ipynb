# %% [markdown]
# # Vehicle injector
# code modified after call with Idneo

# %%
import os

os.chdir("..")

import argparse
import time
import redis
from redistimeseries.client import Client
from tools.vehicle.src.csv_parser import proccess_csv
from tools.vehicle.src.data_handler import order_by_ts_relative
import pandas as pd

# REDIS_PASSWORD = "Success6G&Idneo"
REDIS_PORT = 6379

# %% [markdown]
# ## Install and start the redis database (`redis-stack-server` as it includes redis-timeseries)
#
# ```
# # Install Redis Stack
# curl -fsSL https://packages.redis.io/gpg | sudo gpg --dearmor -o /usr/share/keyrings/redis-archive-keyring.gpg
# echo "deb [signed-by=/usr/share/keyrings/redis-archive-keyring.gpg] https://packages.redis.io/deb $(lsb_release -cs) main" | sudo tee /etc/apt/sources.list.d/redis.list
# sudo apt-get update
# sudo apt-get install redis-stack-server
#
# # Start Redis Stack
# redis-stack-server
# ```

# %% [markdown]
# ## Code from `tools/vehicle/vehicle_injector.py`

# %%
parser = argparse.ArgumentParser(description='Process a CSV dataset file')
parser.add_argument('-f', '--file', required=True, help='Path to CSV file')

# arguments... (file dataset)
args = parser.parse_args()

# Pre-process csv dataset
data_ordered_by_sensor = proccess_csv(args.file)

# Timestamp sorting
data_ordered_by_time = order_by_ts_relative(data_ordered_by_sensor)

# Redis client connectivity
redisClient = redis.Redis(host="127.0.0.1", password=REDIS_PASSWORD, port=REDIS_PORT)
database = redisClient.ts()


# creating Sensors in database if dont exist
for sensor in data_ordered_by_sensor:

    try:
        database.info(sensor["sensor"])
    except redis.exceptions.ConnectionError as connection_error:
        raise SystemExit(connection_error)
    except redis.exceptions.RedisError as e:
        database.create(sensor["sensor"], labels={"type": "can_bus"})

timestamp_start = time.time()
relative_timestamp_start = 0

# iteration of dataset
for data_sample in data_ordered_by_time:
    # delta from dataset
    delta_timestamp = float(list(data_sample.keys())[0])
    # delta of data injection
    delay_of_next_data = round(delta_timestamp - relative_timestamp_start, 2)
    time.sleep(delay_of_next_data)

    relative_timestamp_start = delta_timestamp
    timestamp_epoch_ms = round(timestamp_start + delta_timestamp, 3)
    injection_timestamp = int(timestamp_epoch_ms * 1e3)

    info = data_sample[delta_timestamp]
    print(timestamp_epoch_ms, "Inserting", info['sensor'], info['value'], )
    database.add(info['sensor'], injection_timestamp, info['value'])

# %% [markdown]
# ## Proposed approach

# %%
data_sets = [
    "DS1_stopped_with_ignition_on_22Feb24_115812.csv",
    "DS1_stopped_with_ignition_on_25Jan24_124019.csv",
    "DS1_stopped_with_ignition_on_25Jan24_151531.csv",
    "DS1_stopped_with_ignition_on_25Mar24_153740.CSV",
    "DS2_national_road_90km_h_max_25Jan24_153019.csv",
    "DS2_national_road_90km_h_max_25Mar24_133516.CSV",
    "DS3_highway_120km_h_max_22Feb24_121145.csv",
    "DS3_highway_120km_h_max_25Mar24_154857.csv",
]
file = "tools/vehicle/datasets/ateca_R4_2.0l_TDI/" + data_sets[0]

# Pre-process csv dataset
data_ordered_by_sensor = proccess_csv(file)

# Timestamp sorting
data_ordered_by_time = order_by_ts_relative(data_ordered_by_sensor)
# Out:
# ['Vehicle speed', 'Time since engine start', 'Normed load value', 'Accelerator pedal position', 'Engine torque', 'Oil fill level', 'Engine oil temperature', 'Fuel level', 'Fuel consumption', 'Brake pressure', 'Engaged gear: raw signal-Bits 0-7', 'Efficiency of the SCR catalytic converter']
# Dataset has begun after  0 seconds...

# %%
data_ordered_by_time[:2]
# Out:
# [{0.14: {'sensor': 'Efficiency_of_the_SCR_catalytic_converter', 'value': 0.0}},
#  {0.36: {'sensor': 'Time_since_engine_start', 'value': 0.0}}]

# %%
def batch_insert_timeseries(rts_client, data, batch_size=10):
    pipe = rts_client.redis.pipeline()
    
    for i, item in enumerate(data, 1):
        sensor_id = list(item.values())[0]["sensor"]
        # * 1000 to convert to ms
        timestamp = int(time.time()) - 1800 + int(list(item.keys())[0] * 1000)
        value = list(item.values())[0]["value"]
        
        # Create the time series if it doesn't exist
        try:
            rts_client.create(sensor_id)
        except:
            pass  # Time series already exists
        
        # Add to pipeline
        pipe.execute_command('TS.ADD', sensor_id, timestamp, value)
        
        # Execute batch if batch size reached
        if i % batch_size == 0:
            pipe.execute()
            print(f"Inserted {i} data points")
    
    # Execute any remaining commands in the pipeline
    if i % batch_size != 0:
        pipe.execute()
    
    print(f"Total inserted: {i} data points")


def get_all_timeseries_keys(redis_client):
    keys = []
    cursor = 0
    while True:
        cursor, batch = redis_client.scan(cursor, match='*', count=1000)
        for key in batch:
            # Check if the key is a time series
            if redis_client.type(key) == b'TSDB-TYPE':
                keys.append(key.decode('utf-8'))
        if cursor == 0:
            break
    return keys


def transform_sensor_data(sensor_dict, window_size='1H'):
    # Create a dictionary to hold DataFrames for each sensor
    sensor_dfs = {}
    
    for sensor_id, data in sensor_dict.items():
        # Convert data to DataFrame
        df = pd.DataFrame(data, columns=['timestamp', 'value'])
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
        df.set_index('timestamp', inplace=True)
        df = df.sort_index()  # Ensure timestamps are sorted
        
        # Resample to the specified window size and calculate mean
        sensor_dfs[sensor_id] = df.resample(window_size).mean()
    
    # Combine all sensor DataFrames
    combined_df = pd.concat(sensor_dfs, axis=1)
    
    # Rename columns to include sensor IDs
    combined_df.columns = [f"{sensor}_{col}" for sensor, col in combined_df.columns]
    
    return combined_df

# %%
redisClient = redis.Redis(host="127.0.0.1", port=REDIS_PORT)
rts = Client(redisClient)
redisClient.ping()
# Out:
# True

# %%
# Get all time series keys
sensors = get_all_timeseries_keys(redisClient)

# %%
# Execute batch insert
batch_insert_timeseries(rts, data_ordered_by_time)

# Query example
end_time = int(time.time())
start_time = end_time - 3600  # Last hour


results = {}
for sensor in sensors:
    result = rts.range(sensor, start_time, end_time)
    results[sensor] = result
    # print(f"Data for {sensor}:")
    # print(result)
# Out:
# Inserted 10 data points
# Inserted 20 data points
# Inserted 30 data points
# Inserted 40 data points
# Inserted 50 data points
# Inserted 60 data points
# Inserted 70 data points
# Inserted 80 data points
# Inserted 90 data points
# Inserted 100 data points
# Inserted 110 data points
# Inserted 120 data points
# Inserted 130 data points
# Inserted 140 data points
# Inserted 150 data points
# Inserted 160 data points
# Inserted 170 data points
# Inserted 180 data points
# Inserted 190 data points
# Inserted 200 data points
# Inserted 210 data points
# Inserted 220 data points
# Inserted 230 data points
# Inserted 240 data points
# Inserted 250 data points
# Inserted 260 data points
# Inserted 270 data points
# Inserted 280 data points
# Inserted 290 data points
# Inserted 300 data points
# Inserted 310 data points
# Inserted 320 data points
# Inserted 330 data points
# Inserted 340 data points
# Inserted 350 data points
# Inserted 360 data points
# Inserted 370 data points
# Inserted 380 data points
# Inserted 390 data points
# Inserted 400 data points
# Inserted 410 data points
# Inserted 420 data points
# Inserted 430 data points
# Inserted 440 data points
# Inserted 450 data points
# Inserted 460 data points
# Inserted 470 data points
# Inserted 480 data points
# Inserted 490 data points
# Inserted 500 data points
# Inserted 510 data points
# Inserted 520 data points
# Inserted 530 data points
# Inserted 540 data points
# Inserted 550 data points
# Inserted 560 data points
# Inserted 570 data points
# Inserted 580 data points
# Inserted 590 data points
# Inserted 600 data points
# Inserted 610 data points
# Inserted 620 data points
# Inserted 630 data points
# Inserted 640 data points
# Inserted 650 data points
# Inserted 660 data points
# Inserted 670 data points
# Inserted 680 data points
# Inserted 690 data points
# Inserted 700 data points
# Inserted 710 data points
# Inserted 720 data points
# Inserted 730 data points
# Inserted 740 data points
# Inserted 750 data points
# Inserted 760 data points
# Inserted 770 data points
# Inserted 780 data points
# Inserted 790 data points
# Inserted 800 data points
# Inserted 810 data points
# Inserted 820 data points
# Inserted 830 data points
# Inserted 840 data points
# Inserted 850 data points
# Inserted 860 data points
# Inserted 870 data points
# Inserted 880 data points
# Inserted 890 data points
# Inserted 900 data points
# Inserted 910 data points
# Inserted 920 data points
# Inserted 930 data points
# Inserted 940 data points
# Inserted 950 data points
# Inserted 960 data points
# Inserted 970 data points
# Inserted 980 data points
# Inserted 990 data points
# Inserted 1000 data points
# Inserted 1010 data points
# Inserted 1020 data points
# Inserted 1030 data points
# Inserted 1040 data points
# Inserted 1050 data points
# Inserted 1060 data points
# Inserted 1070 data points
# Inserted 1080 data points
# Inserted 1090 data points
# Inserted 1100 data points
# Inserted 1110 data points
# Inserted 1120 data points
# Inserted 1130 data points
# Inserted 1140 data points
# Inserted 1150 data points
# Inserted 1160 data points
# Inserted 1170 data points
# Inserted 1180 data points
# Inserted 1190 data points
# Inserted 1200 data points
# Inserted 1210 data points
# Inserted 1220 data points
# Inserted 1230 data points
# Inserted 1240 data points
# Inserted 1250 data points
# Inserted 1260 data points
# Inserted 1270 data points
# Inserted 1280 data points
# Inserted 1290 data points
# Inserted 1300 data points
# Inserted 1310 data points
# Inserted 1320 data points
# Inserted 1330 data points
# Inserted 1340 data points
# Inserted 1350 data points
# Inserted 1360 data points
# Inserted 1370 data points
# Inserted 1380 data points
# Inserted 1390 data points
# Inserted 1400 data points
# Inserted 1410 data points
# Inserted 1420 data points
# Inserted 1430 data points
# Inserted 1440 data points
# Inserted 1450 data points
# Inserted 1460 data points
# Inserted 1470 data points
# Inserted 1480 data points
# Inserted 1490 data points
# Inserted 1500 data points
# Inserted 1510 data points
# Inserted 1520 data points
# Inserted 1530 data points
# Inserted 1540 data points
# Inserted 1550 data points
# Inserted 1560 data points
# Inserted 1570 data points
# Inserted 1580 data points
# Inserted 1590 data points
# Inserted 1600 data points
# Inserted 1610 data points
# Inserted 1620 data points
# Inserted 1630 data points
# Inserted 1640 data points
# Inserted 1650 data points
# Inserted 1660 data points
# Inserted 1670 data points
# Inserted 1680 data points
# Inserted 1690 data points
# Inserted 1700 data points
# Inserted 1710 data points
# Inserted 1720 data points
# Inserted 1730 data points
# Inserted 1740 data points
# Inserted 1750 data points
# Inserted 1760 data points
# Inserted 1770 data points
# Inserted 1780 data points
# Inserted 1790 data points
# Inserted 1800 data points
# Inserted 1810 data points
# Inserted 1820 data points
# Inserted 1830 data points
# Inserted 1840 data points
# Inserted 1850 data points
# Inserted 1860 data points
# Inserted 1870 data points
# Inserted 1880 data points
# Inserted 1890 data points
# Inserted 1900 data points
# Inserted 1910 data points
# Inserted 1920 data points
# Inserted 1930 data points
# Inserted 1940 data points
# Inserted 1950 data points
# Inserted 1960 data points
# Inserted 1970 data points
# Inserted 1980 data points
# Inserted 1990 data points
# Inserted 2000 data points
# Inserted 2010 data points
# Inserted 2020 data points
# Inserted 2030 data points
# Inserted 2040 data points
# Inserted 2050 data points
# Inserted 2060 data points
# Inserted 2070 data points
# Inserted 2080 data points
# Inserted 2090 data points
# Inserted 2100 data points
# Inserted 2110 data points
# Inserted 2120 data points
# Inserted 2130 data points
# Inserted 2140 data points
# Inserted 2150 data points
# Inserted 2160 data points
# Inserted 2170 data points
# Inserted 2180 data points
# Inserted 2190 data points
# Inserted 2200 data points
# Inserted 2210 data points
# Inserted 2220 data points
# Inserted 2230 data points
# Inserted 2240 data points
# Inserted 2250 data points
# Inserted 2260 data points
# Inserted 2270 data points
# Inserted 2280 data points
# Inserted 2290 data points
# Inserted 2300 data points
# Inserted 2310 data points
# Inserted 2320 data points
# Inserted 2330 data points
# Inserted 2340 data points
# Inserted 2350 data points
# Inserted 2360 data points
# Inserted 2370 data points
# Inserted 2380 data points
# Inserted 2390 data points
# Inserted 2400 data points
# Inserted 2410 data points
# Inserted 2420 data points
# Inserted 2430 data points
# Inserted 2440 data points
# Inserted 2450 data points
# Inserted 2460 data points
# Inserted 2470 data points
# Inserted 2480 data points
# Inserted 2490 data points
# Inserted 2500 data points
# Inserted 2510 data points
# Inserted 2520 data points
# Inserted 2530 data points
# Inserted 2540 data points
# Inserted 2550 data points
# Inserted 2560 data points
# Inserted 2570 data points
# Inserted 2580 data points
# Inserted 2590 data points
# Inserted 2600 data points
# Inserted 2610 data points
# Inserted 2620 data points
# Inserted 2630 data points
# Inserted 2640 data points
# Inserted 2650 data points
# Inserted 2660 data points
# Inserted 2670 data points
# Inserted 2680 data points
# Inserted 2690 data points
# Inserted 2700 data points
# Inserted 2710 data points
# Inserted 2720 data points
# Inserted 2730 data points
# Inserted 2740 data points
# Inserted 2750 data points
# Inserted 2760 data points
# Inserted 2770 data points
# Inserted 2780 data points
# Inserted 2790 data points
# Inserted 2800 data points
# Inserted 2810 data points
# Inserted 2820 data points
# Inserted 2830 data points
# Inserted 2840 data points
# Inserted 2850 data points
# Inserted 2860 data points
# Inserted 2870 data points
# Inserted 2880 data points
# Inserted 2890 data points
# Inserted 2900 data points
# Inserted 2910 data points
# Inserted 2920 data points
# Inserted 2930 data points
# Inserted 2940 data points
# Inserted 2950 data points
# Inserted 2960 data points
# Inserted 2970 data points
# Inserted 2980 data points
# Inserted 2990 data points
# Inserted 3000 data points
# Inserted 3010 data points
# Inserted 3020 data points
# Inserted 3030 data points
# Inserted 3040 data points
# Inserted 3050 data points
# Inserted 3060 data points
# Inserted 3070 data points
# Inserted 3080 data points
# Inserted 3090 data points
# Inserted 3100 data points
# Inserted 3110 data points
# Inserted 3120 data points
# Inserted 3130 data points
# Inserted 3140 data points
# Inserted 3150 data points
# Inserted 3160 data points
# Inserted 3170 data points
# Inserted 3180 data points
# Inserted 3190 data points
# Inserted 3200 data points
# Inserted 3210 data points
# Inserted 3220 data points
# Inserted 3230 data points
# Inserted 3240 data points
# Inserted 3250 data points
# Inserted 3260 data points
# Inserted 3270 data points
# Inserted 3280 data points
# Inserted 3290 data points
# Inserted 3300 data points
# Inserted 3310 data points
# Inserted 3320 data points
# Inserted 3330 data points
# Inserted 3340 data points
# Inserted 3350 data points
# Inserted 3360 data points
# Inserted 3370 data points
# Inserted 3380 data points
# Inserted 3390 data points
# Inserted 3400 data points
# Inserted 3410 data points
# Inserted 3420 data points
# Inserted 3430 data points
# Inserted 3440 data points
# Inserted 3450 data points
# Inserted 3460 data points
# Inserted 3470 data points
# Inserted 3480 data points
# Inserted 3490 data points
# Inserted 3500 data points
# Inserted 3510 data points
# Inserted 3520 data points
# Inserted 3530 data points
# Inserted 3540 data points
# Inserted 3550 data points
# Inserted 3560 data points
# Inserted 3570 data points
# Inserted 3580 data points
# Inserted 3590 data points
# Inserted 3600 data points
# Inserted 3610 data points
# Inserted 3620 data points
# Inserted 3630 data points
# Inserted 3640 data points
# Inserted 3650 data points
# Inserted 3660 data points
# Inserted 3670 data points
# Inserted 3680 data points
# Inserted 3690 data points
# Inserted 3700 data points
# Inserted 3710 data points
# Inserted 3720 data points
# Inserted 3730 data points
# Inserted 3740 data points
# Inserted 3750 data points
# Inserted 3760 data points
# Inserted 3770 data points
# Inserted 3780 data points
# Inserted 3790 data points
# Inserted 3800 data points
# Inserted 3810 data points
# Inserted 3820 data points
# Inserted 3830 data points
# Inserted 3840 data points
# Inserted 3850 data points
# Inserted 3860 data points
# Inserted 3870 data points
# Inserted 3880 data points
# Inserted 3890 data points
# Inserted 3900 data points
# Inserted 3910 data points
# Inserted 3920 data points
# Inserted 3930 data points
# Inserted 3940 data points
# Inserted 3950 data points
# Inserted 3960 data points
# Inserted 3970 data points
# Inserted 3980 data points
# Inserted 3990 data points
# Inserted 4000 data points
# Inserted 4010 data points
# Inserted 4020 data points
# Inserted 4030 data points
# Inserted 4040 data points
# Inserted 4050 data points
# Inserted 4060 data points
# Inserted 4070 data points
# Inserted 4080 data points
# Inserted 4090 data points
# Inserted 4100 data points
# Inserted 4110 data points
# Inserted 4120 data points
# Inserted 4130 data points
# Inserted 4140 data points
# Inserted 4150 data points
# Inserted 4160 data points
# Inserted 4170 data points
# Inserted 4180 data points
# Inserted 4190 data points
# Inserted 4200 data points
# Inserted 4210 data points
# Inserted 4220 data points
# Inserted 4230 data points
# Inserted 4240 data points
# Inserted 4250 data points
# Inserted 4260 data points
# Inserted 4270 data points
# Inserted 4280 data points
# Inserted 4290 data points
# Inserted 4300 data points
# Inserted 4310 data points
# Inserted 4320 data points
# Inserted 4330 data points
# Inserted 4340 data points
# Inserted 4350 data points
# Inserted 4360 data points
# Inserted 4370 data points
# Inserted 4380 data points
# Inserted 4390 data points
# Inserted 4400 data points
# Inserted 4410 data points
# Inserted 4420 data points
# Inserted 4430 data points
# Inserted 4440 data points
# Inserted 4450 data points
# Inserted 4460 data points
# Inserted 4470 data points
# Inserted 4480 data points
# Inserted 4490 data points
# Inserted 4500 data points
# Inserted 4510 data points
# Inserted 4520 data points
# Inserted 4530 data points
# Inserted 4540 data points
# Inserted 4550 data points
# Inserted 4560 data points
# Inserted 4570 data points
# Inserted 4580 data points
# Inserted 4590 data points
# Inserted 4600 data points
# Inserted 4610 data points
# Inserted 4620 data points
# Inserted 4630 data points
# Inserted 4640 data points
# Inserted 4650 data points
# Inserted 4660 data points
# Inserted 4670 data points
# Inserted 4680 data points
# Inserted 4690 data points
# Inserted 4700 data points
# Inserted 4710 data points
# Inserted 4720 data points
# Inserted 4730 data points
# Inserted 4740 data points
# Inserted 4750 data points
# Inserted 4760 data points
# Inserted 4770 data points
# Inserted 4780 data points
# Inserted 4790 data points
# Inserted 4800 data points
# Inserted 4810 data points
# Inserted 4820 data points
# Inserted 4830 data points
# Inserted 4840 data points
# Inserted 4850 data points
# Inserted 4860 data points
# Inserted 4870 data points
# Inserted 4880 data points
# Inserted 4890 data points
# Inserted 4900 data points
# Inserted 4910 data points
# Inserted 4920 data points
# Inserted 4930 data points
# Inserted 4940 data points
# Inserted 4950 data points
# Inserted 4960 data points
# Inserted 4970 data points
# Inserted 4980 data points
# Inserted 4990 data points
# Inserted 5000 data points
# Inserted 5010 data points
# Inserted 5020 data points
# Inserted 5030 data points
# Inserted 5040 data points
# Inserted 5050 data points
# Inserted 5060 data points
# Inserted 5070 data points
# Inserted 5080 data points
# Inserted 5090 data points
# Inserted 5100 data points
# Inserted 5110 data points
# Inserted 5120 data points
# Inserted 5130 data points
# Inserted 5140 data points
# Total inserted: 5147 data points

# %%
results_pd = transform_sensor_data(results, window_size='5min')
results_pd.head()
# Out:
#                      Normed_load_value_value  Engine_torque_value  \
# timestamp
# 2024-10-16 12:20:00                      NaN                  NaN
# 2024-10-16 12:25:00                     23.1                  NaN
# 2024-10-16 12:30:00                     23.1                 48.4
# 2024-10-16 12:35:00                     23.1                 48.4
# 2024-10-16 12:40:00                     23.1                 48.4
#
#                      Accelerator_pedal_position_value  Fuel_level_value  \
# timestamp
# 2024-10-16 12:20:00                               NaN               NaN
# 2024-10-16 12:25:00                              14.5               NaN
# 2024-10-16 12:30:00                              14.5               NaN
# 2024-10-16 12:35:00                              14.5              24.0
# 2024-10-16 12:40:00                              14.5              24.0
#
#                      Oil_fill_level_value  \
# timestamp
# 2024-10-16 12:20:00                   NaN
# 2024-10-16 12:25:00                   NaN
# 2024-10-16 12:30:00                75.024
# 2024-10-16 12:35:00                75.024
# 2024-10-16 12:40:00                75.024
#
#                      Engaged_gear:_raw_signal-Bits_0-7_value  \
# timestamp
# 2024-10-16 12:20:00                                      NaN
# 2024-10-16 12:25:00                                      NaN
# 2024-10-16 12:30:00                                      NaN
# 2024-10-16 12:35:00                                      NaN
# 2024-10-16 12:40:00                                      0.0
#
#                      Brake_pressure_value  Engine_oil_temperature_value  \
# timestamp
# 2024-10-16 12:20:00                   NaN                           NaN
# 2024-10-16 12:25:00                   NaN                           NaN
# 2024-10-16 12:30:00                   NaN                          13.0
# 2024-10-16 12:35:00                   NaN                           NaN
# 2024-10-16 12:40:00                  3.63                          13.0
#
#                      Time_since_engine_start_value  \
# timestamp
# 2024-10-16 12:20:00                            0.0
# 2024-10-16 12:25:00                            NaN
# 2024-10-16 12:30:00                            0.0
# 2024-10-16 12:35:00                            0.0
# 2024-10-16 12:40:00                            0.0
#
#                      Efficiency_of_the_SCR_catalytic_converter_value  \
# timestamp
# 2024-10-16 12:20:00                                              0.0
# 2024-10-16 12:25:00                                              0.0
# 2024-10-16 12:30:00                                              0.0
# 2024-10-16 12:35:00                                              0.0
# 2024-10-16 12:40:00                                              NaN
#
#                      Vehicle_speed_value  Fuel_consumption_value
# timestamp
# 2024-10-16 12:20:00                  NaN                     NaN
# 2024-10-16 12:25:00                  NaN                     NaN
# 2024-10-16 12:30:00                  NaN                     NaN
# 2024-10-16 12:35:00                  NaN                    1.15
# 2024-10-16 12:40:00                  NaN                     NaN
